# %%
from my_research_life import failure

# %%
from my_research_life import temporary_success
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /work/dante/scripts/my_research_life/demo.ipynb Cell 2 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2B166.111.121.30/work/dante/scripts/my_research_life/demo.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from my_research_life import temporary_success
#
# File /work/dante/scripts/my_research_life/my_research_life/temporary_success.py:14, in <module>
#       9     raise NotImplementedError("Success is not implemented yet.")
#      10     # plt.imshow(plt.imread(os.path.join(path,'failure.png')))
#      11     # plt.axis('off')
# ---> 14 plot_success()
#
# File /work/dante/scripts/my_research_life/my_research_life/temporary_success.py:9, in plot_success()
#       7 def plot_success():
#       8     """Plot a temporary success."""
# ----> 9     raise NotImplementedError("Success is not implemented yet.")
# ...
